# %% [markdown]
# Trabalho Individual 1

# %% [markdown]
# # Setup

# %%
import sympy as sp


def math(x):
    from IPython.display import display, Math

    return display(Math(x))


def show(x):
    from IPython.display import display, Math

    return display(Math(sp.latex(x)))

# %% [markdown]
# # Tarefa

# %% [markdown]
# ![Enunciado](img/trabalho_2_tarefa_1.png)

# %% [markdown]
# Primeiro vamos criar todos os símbolos fornecidos pela questão e configurar as respectivas substituições numéricas paraencontrar valores no final

# %%
# Constantes comuns
t = sp.symbols("t", real=True)
num_subs = {t: 2}

# Constantes da opção
X1, Y1, a, b, c = sp.symbols("X_1, Y_11, a, b, c", real=True)
num_subs.update({X1: 105, Y1: 205, a: 22, b: 105, c: 82})  # Opção I

# %% [markdown]
# Precisamos também criar os símbolos intermediários que desejamos encontrar

# %%
# Variáveis e incógnitas
center = ju8  bb  sp.symbols("x_c, y_c", real=True))
M = sp.Matrix(sp.symbols("M_x, M_y"), real=True)
I = sp.Matrix(2, 2, sp.symbols("I_xy, I_xx, I_yy, I_xy"), real=True)

# %% [markdown]
# Então, configuramos novos valores para as variáveis intermediárias. Para preservar os valores originais e permitir inspeção mais fácil das expressões, criaremos essas relações como um dicionário de substituições numéricas

# %% [markdown]
# O primeiro valor que precisamos é a posição do centróide da seção. Aqui, calculamos sua posição a partir de um ponto arbitrário no canto inferior esquerdo da seção.

# %%
# Sub áreas da seção
A = a * t, (b - 2 * t) * t, c * t

# coordenadas do centro
sym_subs = {
    center: sp.Matrix(
        (
            sp.simplify((A[0] * a / 2 + A[1] * t / 2 + A[2] * c / 2) / sum(A)),
            sp.simplify((A[0] * (b - t / 2) + A[1] * b / 2 + A[2] * t / 2) / sum(A)),
        )
    )
}

# Exibe as substituições realizadas e valores numéricos
math(f"(\\bar{{x}}, \\bar{{y}}) = {sp.latex(center)}")
math(f"(\\bar{{x}}, \\bar{{y}}) = " + sp.latex(center.subs(sym_subs)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e1ec0b544b26> in <module>
#       3
#       4 # coordenadas do centro
# ----> 5 sym_subs = {
#       6     center: sp.Matrix(
#       7         (
#
# TypeError: unhashable type: 'MutableDenseMatrix'

# %%
sym_subs.update(
    {
        "I_xx": (
            A[0] * t ** 2 / 12
            + A[0] * (b - t / 2 - y_) ** 2
            + A[1] * (b - 2 * t) ** 2 / 12
            + A[1] * (b / 2 - y_) ** 2
            + A[2] * t ** 2 / 12
            + A[2] * (t / 2 - y_) ** 2
        ),
        "I_yy": (
            A[0] * a ** 2 / 12
            + A[0] * (a / 2 - x_) ** 2
            + A[1] * t ** 2 / 12
            + A[1] * (t / 2 - y_) ** 2
            + A[2] * c ** 2 / 12
            + A[2] * (c / 2 - y_) ** 2
        ),
        "I_xy": (
            A[0] * (a / 2 - x_) * (b - t / 2 - y_)
            + A[1] * t * (t / 2 - x_) * (b / 2 - y_)
            + A[2] * (c / 2 - x_) * (t / 2 - y_)
        ),
    }
)

math(f"{sp.latex(I)} = {sp.latex(I.subs(sym_subs))}")
math(f"{sp.latex(I)} = {sp.latex(I.subs(sym_subs).evalf(5, subs=num_subs))}")
# Out:
# $\displaystyle \left[\begin{matrix}I_{xy} & I_{xx}\\I_{yy} & I_{xy}\end{matrix}\right] = \left[\begin{matrix}a t \left(\frac{a}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right) \left(b - \frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) + c t \left(\frac{c}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right) \left(\frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) + t^{2} \left(\frac{b}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) \left(b - 2 t\right) \left(\frac{t}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right) & \frac{a t^{3}}{12} + a t \left(b - \frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right)^{2} + \frac{c t^{3}}{12} + c t \left(\frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right)^{2} + t \left(\frac{b}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right)^{2} \left(b - 2 t\right) + \frac{t \left(b - 2 t\right)^{3}}{12}\\\frac{a^{3} t}{12} + a t \left(\frac{a}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right)^{2} + \frac{c^{3} t}{12} + c t \left(\frac{c}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right)^{2} + \frac{t^{3} \left(b - 2 t\right)}{12} + t \left(b - 2 t\right) \left(\frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right)^{2} & a t \left(\frac{a}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right) \left(b - \frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) + c t \left(\frac{c}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right) \left(\frac{t}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) + t^{2} \left(\frac{b}{2} - \frac{a \left(2 b - t\right) + b \left(b - 2 t\right) + c t}{2 \left(a + b + c - 2 t\right)}\right) \left(b - 2 t\right) \left(\frac{t}{2} - \frac{a^{2} + c^{2} + t \left(b - 2 t\right)}{2 \left(a + b + c - 2 t\right)}\right)\end{matrix}\right]$
# $\displaystyle \left[\begin{matrix}I_{xy} & I_{xx}\\I_{yy} & I_{xy}\end{matrix}\right] = \left[\begin{matrix}-2.6165 \cdot 10^{5} & 6.303 \cdot 10^{5}\\3.6607 \cdot 10^{5} & -2.6165 \cdot 10^{5}\end{matrix}\right]$

# %%
alpha, E, rho, z = sp.symbols("alpha, E, rho, z", real=True)
num_subs[z] = 2000
sym_subs.update({
    "M_x": -Y1 * z,
    "M_y": X1 * z
})
math(sp.latex(M) + "=" + sp.latex(M.subs(sym_subs)))
math(sp.latex(M) + "=" + sp.latex(M.subs(sym_subs).evalf(5, subs=num_subs)))
# Out:
# $\displaystyle \left[\begin{matrix}M_{x}\\M_{y}\end{matrix}\right]=\left[\begin{matrix}- Y_{11} z\\X_{1} z\end{matrix}\right]$
# $\displaystyle \left[\begin{matrix}M_{x}\\M_{y}\end{matrix}\right]=\left[\begin{matrix}-4.1 \cdot 10^{5}\\2.1 \cdot 10^{5}\end{matrix}\right]$

# %%
rot = (I.inv() * M)
rot.subs(sym_subs).evalf(5, num_subs)
# Out:
# Matrix([
# [ 0.15459],
# [-0.58631]])

# %%
tan_alpha = sp.simplify(rot[0]/rot[1])
math(r"\tan\alpha = " + sp.latex(tan_alpha))
math(r"\tan\alpha = " + sp.latex(tan_alpha.subs(sym_subs).evalf(5, subs=num_subs)))
# Out:
# $\displaystyle \tan\alpha = \frac{- I_{xx} M_{y} + I_{xy} M_{x}}{I_{xy} M_{y} - I_{yy} M_{x}}$
# $\displaystyle \tan\alpha = -0.26367$

# %%
(sp.atan2(rot[0], rot[1])* 180 / sp.pi).subs(sym_subs).evalf(5, subs=num_subs)
# Out:
# 165.23

# %%
xp, yp = sp.symbols("x_p, y_p")
p = sp.Matrix([xp - x_, yp - y_])
sigma = p.T * rot

p_of_interest = (
    (0, 0),
    (0, b),
    (a, b),
    (a, b - t),
    (c, 0),
    (c, t),
)

for coords in p_of_interest:
    s_ = (
        sigma.subs({xp: coords[0], yp: coords[1]})
        .subs(sym_subs)
        .evalf(5, subs=num_subs)
    )
    math(f"\\sigma_{{{sp.latex(coords)}}} = " + sp.latex(s_))
# Out:
# $\displaystyle \sigma_{\left( 0, \  0\right)} = \left[\begin{matrix}19.15\end{matrix}\right]$
# $\displaystyle \sigma_{\left( 0, \  b\right)} = \left[\begin{matrix}-42.413\end{matrix}\right]$
# $\displaystyle \sigma_{\left( a, \  b\right)} = \left[\begin{matrix}-39.012\end{matrix}\right]$
# $\displaystyle \sigma_{\left( a, \  b - t\right)} = \left[\begin{matrix}-37.839\end{matrix}\right]$
# $\displaystyle \sigma_{\left( c, \  0\right)} = \left[\begin{matrix}31.826\end{matrix}\right]$
# $\displaystyle \sigma_{\left( c, \  t\right)} = \left[\begin{matrix}30.654\end{matrix}\right]$

# %%
p
# Out:
# Matrix([
# [-x_c + x_p],
# [-y_c + y_p]])
